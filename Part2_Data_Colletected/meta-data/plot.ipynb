# %%
import pandas as pd

# %%
allzeros = {"Code Segment-1":[92.5919,96.2945,96.293,96.29,96.2841,96.2722,96.2485,96.2011,96.1063,95.9167,95.5374,94.7789,93.2619,90.2278,84.1597,],"Code Segment-2":[66.6644,83.3272,83.3206,83.3072,83.2806,83.2272,83.1206,82.9072,82.4806,81.6273,79.9207,76.5074,69.681,56.0281,49.9983,],"Code Segment-3":[99.955,99.94,99.9175,99.8576,99.7376,99.4978,99.0181,98.0586,96.1397,92.3019,84.6263,69.2752,50.0037,50.0037,50.0037,]}

# %%
all_zeros = pd.DataFrame(allzeros)
all_zeros.index += 1
all_zeros.plot(title='All Zeros - Correct prediction',xlabel='bits',ylabel="percentage",figsize=(10,5),color={"Code Segment-1":"red","Code Segment-2":"blue","Code Segment-3":"orange"})
# Out:
# <AxesSubplot:title={'center':'All Zeros - Correct prediction'}, xlabel='bits', ylabel='percentage'>

# %%
allones = {"Code Segment-1":[92.5926,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,96.2959,],"Code Segment-2":[66.6678,83.3272,83.3206,83.3072,83.2806,83.2272,83.1206,82.9072,82.4806,81.6273,79.9207,76.5074,69.681,56.0281,50.0017,],"Code Segment-3":[99.955,99.94,99.9175,99.8576,99.7376,99.4978,99.0181,98.0586,96.1397,92.3019,84.6263,69.2752,49.9963,49.9963,49.9963]}

# %%
all_ones = pd.DataFrame(allones)
all_ones.index +=1
all_ones.plot(title='All Ones - Correct prediction',xlabel='bits',ylabel="percentage",figsize=(10,5),color={"Code Segment-1":"red","Code Segment-2":"blue","Code Segment-3":"orange"})
# Out:
# <AxesSubplot:title={'center':'All Ones - Correct prediction'}, xlabel='bits', ylabel='percentage'>

# %%
allrandom = {"Code Segment-1":[92.5919,96.2945,96.293,96.29,96.2959,96.2841,96.2959,96.2959,96.2959,96.2604,95.8811,96.2959,96.2959,95.1226,89.0541,],"Code Segment-2":[66.6644,83.3272,83.3206,83.3072,83.3306,83.2806,83.2772,83.0639,82.6372,83.1739,81.4673,81.7839,74.9575,78.0541,50.7483,],"Code Segment-3":[99.955,99.94,99.9175,99.8576,99.9625,99.7376,99.7227,98.7632,96.8443,99.2579,91.5823,93.0065,62.3042,76.2312,50.0037,]}

# %%
all_random = pd.DataFrame(allrandom)
all_random.index +=1
all_random.plot(title='All Random - Correct prediction',xlabel='bits',ylabel="percentage",figsize=(10,5),color={"Code Segment-1":"red","Code Segment-2":"blue","Code Segment-3":"orange"})
# Out:
# <AxesSubplot:title={'center':'All Random - Correct prediction'}, xlabel='bits', ylabel='percentage'>
