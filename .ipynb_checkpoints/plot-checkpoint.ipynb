# %%
import pandas as pd

# %%
allzeros = {"Code Segment-1":[20000,10003,10005,10009,10017,10033,10065,10129,10257,10513,11025,12049,14097,18193,26385,42769,75537,141073,260000,260000,260000,260000],"Code Segment-2":[19999,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001,10001],"Code Segment-3":[20000,10003,10004,10009,10014,10030,10063,10127,10254,10511,11016,12039,14096,18189,26374,42766,75530,141065,260000,260000,260000,260000]}

# %%
all_zeros = pd.DataFrame(allzeros)
all_zeros
all_zeros.plot.bar(title='All Zeros - Correct prediction',xlabel='bits',ylabel="number of predictions")
# Out:
# <AxesSubplot:title={'center':'All Zeros - Correct prediction'}, xlabel='bits', ylabel='number of predictions'>
